# %%
import matplotlib.pyplot as plt

# %%
plt.plot([20000, 40000, 60000, 80000, 100000], [6.61, 12.56, 18.23, 23.03, 28.30], '^:k', label='t2vec') # t2vec
plt.plot([20000, 40000, 60000, 80000, 100000], [1.19, 4.41, 7.94, 10.52, 14.33], 'o--k', label='Doc2Vec') # D2V
plt.plot([20000, 40000, 60000, 80000, 100000], [1.07, 3.14, 4.53, 5.83, 6.19], 'X-k', label='Word2Vec') # W2V
plt.plot([20000, 40000, 60000, 80000, 100000], [18.72, 37.63, 51.73, 66.26, 90.27], 'd-k', label='BERT') # BERT
plt.plot([20000, 40000, 60000, 80000, 100000], [20.25, 40.60, 55.74, 62.03, 95.30], 's:k', label='SBERT') # SBERT
plt.ylabel('Time (s)')
plt.xlabel('Database size (Porto)')
plt.axis([10000, 110000, 0, 100])
plt.legend()
plt.show()
